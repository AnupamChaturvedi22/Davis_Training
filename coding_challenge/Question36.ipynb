# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/coding_challenge/Question36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def final_price(price,discount):
    discounted_amount = (price * discount) / 100
    return price - discounted_amount

price = float(input("Enter the original price "))
discount = float(input("Enter the discount percentage "))

final_price(price,discount)
