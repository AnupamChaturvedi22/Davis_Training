# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/coding_challenge/Question21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter price "))
discount = float(input("Enter discount % "))

if discount > 0:
    final = price - (price * discount / 100)
else:
    final = price

print("Final Price =", final)
