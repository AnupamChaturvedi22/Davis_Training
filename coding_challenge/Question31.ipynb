# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/coding_challenge/Question31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def discounted_bill(price,discount):
  final_price = price - (price * discount / 100)
  print (final_price)

price = int(input("Enter the price: "))
discount = int(input("Enter the discount: "))
discounted_bill(price,discount)
