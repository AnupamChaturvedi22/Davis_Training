# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/coding_challenge/Question9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Even_list(n):
  for i in range (2,n+1,2):
    print(i)

n = int(input("Enter N "))
result = Even_list(n)
print(result)
