# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/coding_challenge/Question7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_eligibility(age):
  if age >= 18:
    print("Eligible for vote")
  else:
    print("Not Eligible for vote")

age = int(input("Enter your age "))
result = check_eligibility(age)
print(result)
