# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/classwork/add(using_func).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_numbers(num1,num2):
  return (num1 + num2)

number1 = int(input("Enter first number: "))
number2 = int(input("Enter second number: "))

print("Sum = ",add_numbers(number1,number2))
# Out:
# Enter first number: 65
# Enter second number: 65
# Sum =  130
