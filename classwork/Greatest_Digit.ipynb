# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/classwork/Greatest_Digit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

greatest = 0

while num > 0:
    digit = num % 10

    if digit > greatest:
        greatest = digit

    num = num // 10

print("Greatest digit is:", greatest)
# Out:
# Enter a number: 53542354
# Greatest digit is: 5
