# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/classwork/ReadFile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filev = open("firstfile.txt","r")
if(filev.mode == "r"):
    data = filev.read()
    print(data)
    print("---------------------------")
    print("No. of characters : ", len(data))
    filev.close()
else:
  print("unable to open the file")
