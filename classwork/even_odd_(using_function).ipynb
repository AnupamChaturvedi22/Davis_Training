# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupamChaturvedi22/Davis_Training/blob/main/classwork/even_odd_(using_function).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd(num):
    if num % 2 == 0:
        print("The number is Even")
    else:
        print("The number is Odd")

# Taking input from user
number = int(input("Enter an integer: "))

# Calling the function
check_even_odd(number)
